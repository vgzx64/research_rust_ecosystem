# %%
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('../utils')
import database as db

# %%
def print_statistics(df_frame, col):
    print(f"# average {col}: " + str(df_frame[col].sum() / len(df_frame)))
    print(f"# median {col}: " + str(df_frame[col].median()))
    print(f"# minimum {col}: " + str(df_frame[col].min()))
    print(f"# maximum {col}: " + str(df_frame[col].max()))
    print(f"# total {col}: " + str(df_frame[col].sum()))
    print(f"std of {col}: " + str(df_frame[col].std()))
    print("==================================")


def load_commit_locality_frame():
    df_base = pd.read_sql(
        "SELECT cve_id, hash, safe_func, unsafe_func, unsafe_block FROM total_safe_unsafe",
        con=db.conn,
    )
    df_base[["safe_func", "unsafe_func", "unsafe_block"]] = df_base[[
        "safe_func",
        "unsafe_func",
        "unsafe_block",
    ]].apply(pd.to_numeric)

    df_func_fix = pd.read_sql(
        """
        SELECT
            cve_id,
            hash,
            SUM(CASE WHEN unsafety = 'False' THEN 1 ELSE 0 END) AS safe_func_fix,
            SUM(CASE WHEN unsafety = 'True' THEN 1 ELSE 0 END) AS unsafe_func_fix
        FROM function_fix
        GROUP BY cve_id, hash
        """,
        con=db.conn,
    )
    df_block_fix = pd.read_sql(
        """
        SELECT
            cve_id,
            hash,
            COUNT(*) AS unsafe_block_fix
        FROM unsafe_block_fix
        GROUP BY cve_id, hash
        """,
        con=db.conn,
    )
    df_vul = pd.read_sql(
        "SELECT id, package, severity FROM cve",
        con=db.conn,
    )

    df_data = (
        df_base.merge(df_func_fix, on=["cve_id", "hash"], how="left")
        .merge(df_block_fix, on=["cve_id", "hash"], how="left")
        .merge(df_vul, left_on="cve_id", right_on="id", how="left")
        .drop(columns=["id"])
    )

    for col in ["safe_func_fix", "unsafe_func_fix", "unsafe_block_fix"]:
        df_data[col] = pd.to_numeric(df_data[col]).fillna(0).astype(int)

    return df_data

# %% [markdown]
# ### safe/unsafe in commit locality

# %%
df_data = load_commit_locality_frame()

print_statistics(df_data, 'safe_func')
print_statistics(df_data, 'unsafe_func')
print_statistics(df_data, 'unsafe_block')
print_statistics(df_data, 'safe_func_fix')
print_statistics(df_data, 'unsafe_func_fix')
print_statistics(df_data, 'unsafe_block_fix')
# Out:
# # average safe_func: 2726.6018018018017
# # median safe_func: 850.0
# # minimum safe_func: 1
# # maximum safe_func: 19805
# # total safe_func: 1513264
# std of safe_func: 3862.504510763012
# ==================================
# # average unsafe_func: 34.23243243243243
# # median unsafe_func: 2.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 4448
# # total unsafe_func: 18999
# std of unsafe_func: 219.6222348079787
# ==================================
# # average unsafe_block: 176.2882882882883
# # median unsafe_block: 25.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 9041
# # total unsafe_block: 97840
# std of unsafe_block: 548.2252427058103
# ==================================
# # average safe_func_fix: 1638.7243243243242
# # median safe_func_fix: 615.0
# # minimum safe_func_fix: 0
# # maximum safe_func_fix: 13469
# # total safe_func_fix: 909492
# std of safe_func_fix: 2238.4698449991315
# ==================================
# # average unsafe_func_fix: 21.117117117117118
# # median unsafe_func_fix: 1.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 2676
# # total unsafe_func_fix: 11720
# std of unsafe_func_fix: 133.95022640566478
# ==================================
# # average unsafe_block_fix: 116.0
# # median unsafe_block_fix: 19.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 6481
# # total unsafe_block_fix: 64380
# std of unsafe_block_fix: 353.36220053274366
# ==================================

# %% [markdown]
# ### safe/unsafe in commit locality across type

# %%
df_data = load_commit_locality_frame()
df_types = pd.read_sql("SELECT cve_id, sfp_category FROM cve_sfp", con=db.conn)
df_data = df_data.merge(df_types, on='cve_id', how='left')

for category in sorted(df_data['sfp_category'].dropna().unique()):
    df_category = df_data[df_data['sfp_category'] == category]
    if df_category.empty:
        print(f"Category {category} is empty")
        continue

    print(f"Commit Locality Across {category}")
    print(f"Number of rows: {len(df_category)}")
    print_statistics(df_category, 'safe_func')
    print_statistics(df_category, 'unsafe_func')
    print_statistics(df_category, 'unsafe_block')
    print_statistics(df_category, 'safe_func_fix')
    print_statistics(df_category, 'unsafe_func_fix')
    print_statistics(df_category, 'unsafe_block_fix')
    print("\n")
# Out:
# Commit Locality Across API
# Number of rows: 9
# # average safe_func: 5265.666666666667
# # median safe_func: 2471.0
# # minimum safe_func: 20
# # maximum safe_func: 13663
# # total safe_func: 47391
# std of safe_func: 5424.2899074441075
# ==================================
# # average unsafe_func: 118.66666666666667
# # median unsafe_func: 10.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 771
# # total unsafe_func: 1068
# std of unsafe_func: 251.56261645960038
# ==================================
# # average unsafe_block: 212.55555555555554
# # median unsafe_block: 111.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 1098
# # total unsafe_block: 1913
# std of unsafe_block: 350.20712125509067
# ==================================
# # average safe_func_fix: 3306.8888888888887
# # median safe_func_fix: 1720.0
# # minimum safe_func_fix: 20
# # maximum safe_func_fix: 9371
# # total safe_func_fix: 29762
# std of safe_func_fix: 3240.1718104309084
# ==================================
# # average unsafe_func_fix: 59.44444444444444
# # median unsafe_func_fix: 8.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 438
# # total unsafe_func_fix: 535
# std of unsafe_func_fix: 142.93802075647255
# ==================================
# # average unsafe_block_fix: 149.77777777777777
# # median unsafe_block_fix: 110.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 732
# # total unsafe_block_fix: 1348
# std of unsafe_block_fix: 230.67497576556596
# ==================================
#
#
# Commit Locality Across Access Control
# Number of rows: 24
# # average safe_func: 5087.916666666667
# # median safe_func: 5202.5
# # minimum safe_func: 146
# # maximum safe_func: 12309
# # total safe_func: 122110
# std of safe_func: 4408.145187349621
# ==================================
# # average unsafe_func: 37.458333333333336
# # median unsafe_func: 4.5
# # minimum unsafe_func: 0
# # maximum unsafe_func: 735
# # total unsafe_func: 899
# std of unsafe_func: 149.00568392037837
# ==================================
# # average unsafe_block: 218.25
# # median unsafe_block: 33.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 1815
# # total unsafe_block: 5238
# std of unsafe_block: 425.5898464382161
# ==================================
# # average safe_func_fix: 2840.9166666666665
# # median safe_func_fix: 2961.5
# # minimum safe_func_fix: 79
# # maximum safe_func_fix: 6832
# # total safe_func_fix: 68182
# std of safe_func_fix: 2431.696954743774
# ==================================
# # average unsafe_func_fix: 16.458333333333332
# # median unsafe_func_fix: 1.5
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 309
# # total unsafe_func_fix: 395
# std of unsafe_func_fix: 62.68969762573272
# ==================================
# # average unsafe_block_fix: 141.625
# # median unsafe_block_fix: 29.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 720
# # total unsafe_block_fix: 3399
# std of unsafe_block_fix: 216.27836581992923
# ==================================
#
#
# Commit Locality Across Authentication
# Number of rows: 21
# # average safe_func: 2935.714285714286
# # median safe_func: 1600.0
# # minimum safe_func: 135
# # maximum safe_func: 10312
# # total safe_func: 61650
# std of safe_func: 3014.6120669641246
# ==================================
# # average unsafe_func: 7.619047619047619
# # median unsafe_func: 1.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 43
# # total unsafe_func: 160
# std of unsafe_func: 14.968220303283188
# ==================================
# # average unsafe_block: 57.23809523809524
# # median unsafe_block: 11.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 304
# # total unsafe_block: 1202
# std of unsafe_block: 87.05395152542172
# ==================================
# # average safe_func_fix: 1922.1904761904761
# # median safe_func_fix: 1126.0
# # minimum safe_func_fix: 110
# # maximum safe_func_fix: 4992
# # total safe_func_fix: 40366
# std of safe_func_fix: 1677.1199306861633
# ==================================
# # average unsafe_func_fix: 3.9047619047619047
# # median unsafe_func_fix: 1.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 23
# # total unsafe_func_fix: 82
# std of unsafe_func_fix: 7.549203679228437
# ==================================
# # average unsafe_block_fix: 34.23809523809524
# # median unsafe_block_fix: 11.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 169
# # total unsafe_block_fix: 719
# std of unsafe_block_fix: 46.085686239769466
# ==================================
#
#
# Commit Locality Across Cryptography
# Number of rows: 50
# # average safe_func: 2005.92
# # median safe_func: 383.0
# # minimum safe_func: 7
# # maximum safe_func: 13098
# # total safe_func: 100296
# std of safe_func: 3216.4158074680913
# ==================================
# # average unsafe_func: 8.28
# # median unsafe_func: 0.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 65
# # total unsafe_func: 414
# std of unsafe_func: 16.97061085091109
# ==================================
# # average unsafe_block: 135.26
# # median unsafe_block: 7.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 1176
# # total unsafe_block: 6763
# std of unsafe_block: 309.6419795670543
# ==================================
# # average safe_func_fix: 1115.66
# # median safe_func_fix: 298.0
# # minimum safe_func_fix: 7
# # maximum safe_func_fix: 5657
# # total safe_func_fix: 55783
# std of safe_func_fix: 1651.9627856904413
# ==================================
# # average unsafe_func_fix: 5.14
# # median unsafe_func_fix: 0.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 54
# # total unsafe_func_fix: 257
# std of unsafe_func_fix: 11.642655563548574
# ==================================
# # average unsafe_block_fix: 77.38
# # median unsafe_block_fix: 6.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 765
# # total unsafe_block_fix: 3869
# std of unsafe_block_fix: 170.22121141716306
# ==================================
#
#
# Commit Locality Across Exception Management
# Number of rows: 58
# # average safe_func: 2576.5
# # median safe_func: 608.0
# # minimum safe_func: 8
# # maximum safe_func: 11720
# # total safe_func: 149437
# std of safe_func: 3443.0094865627952
# ==================================
# # average unsafe_func: 20.017241379310345
# # median unsafe_func: 1.5
# # minimum unsafe_func: 0
# # maximum unsafe_func: 847
# # total unsafe_func: 1161
# std of unsafe_func: 111.09431608296039
# ==================================
# # average unsafe_block: 92.3103448275862
# # median unsafe_block: 23.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 1205
# # total unsafe_block: 5354
# std of unsafe_block: 200.17187412159754
# ==================================
# # average safe_func_fix: 1597.3103448275863
# # median safe_func_fix: 565.0
# # minimum safe_func_fix: 8
# # maximum safe_func_fix: 6524
# # total safe_func_fix: 92644
# std of safe_func_fix: 1997.850557315234
# ==================================
# # average unsafe_func_fix: 18.275862068965516
# # median unsafe_func_fix: 1.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 846
# # total unsafe_func_fix: 1060
# std of unsafe_func_fix: 110.96463686782701
# ==================================
# # average unsafe_block_fix: 77.75862068965517
# # median unsafe_block_fix: 16.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 1204
# # total unsafe_block_fix: 4510
# std of unsafe_block_fix: 190.10461665950436
# ==================================
#
#
# Commit Locality Across Information Leak
# Number of rows: 31
# # average safe_func: 2853.6774193548385
# # median safe_func: 628.0
# # minimum safe_func: 7
# # maximum safe_func: 11720
# # total safe_func: 88464
# std of safe_func: 3769.755079463357
# ==================================
# # average unsafe_func: 6.225806451612903
# # median unsafe_func: 0.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 53
# # total unsafe_func: 193
# std of unsafe_func: 14.486107545781818
# ==================================
# # average unsafe_block: 115.29032258064517
# # median unsafe_block: 0.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 1019
# # total unsafe_block: 3574
# std of unsafe_block: 275.24936494608994
# ==================================
# # average safe_func_fix: 1637.8387096774193
# # median safe_func_fix: 510.0
# # minimum safe_func_fix: 7
# # maximum safe_func_fix: 6524
# # total safe_func_fix: 50773
# std of safe_func_fix: 1962.614516349287
# ==================================
# # average unsafe_func_fix: 3.6129032258064515
# # median unsafe_func_fix: 0.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 32
# # total unsafe_func_fix: 112
# std of unsafe_func_fix: 8.527123076219155
# ==================================
# # average unsafe_block_fix: 66.58064516129032
# # median unsafe_block_fix: 0.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 545
# # total unsafe_block_fix: 2064
# std of unsafe_block_fix: 149.2920569875367
# ==================================
#
#
# Commit Locality Across Memory Access
# Number of rows: 69
# # average safe_func: 1602.9420289855072
# # median safe_func: 164.0
# # minimum safe_func: 1
# # maximum safe_func: 19075
# # total safe_func: 110603
# std of safe_func: 3846.9085712313818
# ==================================
# # average unsafe_func: 66.34782608695652
# # median unsafe_func: 3.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 955
# # total unsafe_func: 4578
# std of unsafe_func: 215.14426255059624
# ==================================
# # average unsafe_block: 277.2173913043478
# # median unsafe_block: 29.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 3291
# # total unsafe_block: 19128
# std of unsafe_block: 714.8236078091783
# ==================================
# # average safe_func_fix: 1088.1884057971015
# # median safe_func_fix: 124.0
# # minimum safe_func_fix: 0
# # maximum safe_func_fix: 12887
# # total safe_func_fix: 75085
# std of safe_func_fix: 2574.8370381064456
# ==================================
# # average unsafe_func_fix: 46.78260869565217
# # median unsafe_func_fix: 3.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 846
# # total unsafe_func_fix: 3228
# std of unsafe_func_fix: 152.1528710333225
# ==================================
# # average unsafe_block_fix: 188.14492753623188
# # median unsafe_block_fix: 22.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 1531
# # total unsafe_block_fix: 12982
# std of unsafe_block_fix: 424.0663195692501
# ==================================
#
#
# Commit Locality Across Memory Management
# Number of rows: 63
# # average safe_func: 346.8253968253968
# # median safe_func: 139.0
# # minimum safe_func: 3
# # maximum safe_func: 2052
# # total safe_func: 21850
# std of safe_func: 498.06517709524786
# ==================================
# # average unsafe_func: 20.126984126984127
# # median unsafe_func: 7.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 139
# # total unsafe_func: 1268
# std of unsafe_func: 34.709621267016786
# ==================================
# # average unsafe_block: 92.61904761904762
# # median unsafe_block: 35.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 933
# # total unsafe_block: 5835
# std of unsafe_block: 176.76104049758257
# ==================================
# # average safe_func_fix: 295.015873015873
# # median safe_func_fix: 117.0
# # minimum safe_func_fix: 3
# # maximum safe_func_fix: 1720
# # total safe_func_fix: 18586
# std of safe_func_fix: 411.4638498628812
# ==================================
# # average unsafe_func_fix: 14.015873015873016
# # median unsafe_func_fix: 6.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 102
# # total unsafe_func_fix: 883
# std of unsafe_func_fix: 23.51285994287578
# ==================================
# # average unsafe_block_fix: 71.93650793650794
# # median unsafe_block_fix: 30.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 610
# # total unsafe_block_fix: 4532
# std of unsafe_block_fix: 127.38079475132731
# ==================================
#
#
# Commit Locality Across Other
# Number of rows: 39
# # average safe_func: 1902.948717948718
# # median safe_func: 563.0
# # minimum safe_func: 8
# # maximum safe_func: 13663
# # total safe_func: 74215
# std of safe_func: 3315.9180514024665
# ==================================
# # average unsafe_func: 24.71794871794872
# # median unsafe_func: 0.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 771
# # total unsafe_func: 964
# std of unsafe_func: 123.91974243074655
# ==================================
# # average unsafe_block: 82.82051282051282
# # median unsafe_block: 7.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 1098
# # total unsafe_block: 3230
# std of unsafe_block: 230.8582239560704
# ==================================
# # average safe_func_fix: 1117.8461538461538
# # median safe_func_fix: 392.0
# # minimum safe_func_fix: 8
# # maximum safe_func_fix: 9371
# # total safe_func_fix: 43596
# std of safe_func_fix: 1984.2651501840212
# ==================================
# # average unsafe_func_fix: 14.974358974358974
# # median unsafe_func_fix: 0.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 438
# # total unsafe_func_fix: 584
# std of unsafe_func_fix: 70.90745903139388
# ==================================
# # average unsafe_block_fix: 53.02564102564103
# # median unsafe_block_fix: 5.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 732
# # total unsafe_block_fix: 2068
# std of unsafe_block_fix: 150.3097656209524
# ==================================
#
#
# Commit Locality Across Path Resolution
# Number of rows: 30
# # average safe_func: 3232.3
# # median safe_func: 831.5
# # minimum safe_func: 10
# # maximum safe_func: 11502
# # total safe_func: 96969
# std of safe_func: 4109.8742169694615
# ==================================
# # average unsafe_func: 32.46666666666667
# # median unsafe_func: 0.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 776
# # total unsafe_func: 974
# std of unsafe_func: 142.3528237752297
# ==================================
# # average unsafe_block: 124.83333333333333
# # median unsafe_block: 9.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 1895
# # total unsafe_block: 3745
# std of unsafe_block: 351.4727716273372
# ==================================
# # average safe_func_fix: 1844.5
# # median safe_func_fix: 640.5
# # minimum safe_func_fix: 10
# # maximum safe_func_fix: 6164
# # total safe_func_fix: 55335
# std of safe_func_fix: 2200.0652145506647
# ==================================
# # average unsafe_func_fix: 14.833333333333334
# # median unsafe_func_fix: 0.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 343
# # total unsafe_func_fix: 445
# std of unsafe_func_fix: 62.56918010371061
# ==================================
# # average unsafe_block_fix: 64.76666666666667
# # median unsafe_block_fix: 6.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 752
# # total unsafe_block_fix: 1943
# std of unsafe_block_fix: 147.43758079229684
# ==================================
#
#
# Commit Locality Across Predictability
# Number of rows: 5
# # average safe_func: 1768.6
# # median safe_func: 1622.0
# # minimum safe_func: 157
# # maximum safe_func: 4508
# # total safe_func: 8843
# std of safe_func: 1651.5293821182836
# ==================================
# # average unsafe_func: 2.4
# # median unsafe_func: 0.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 12
# # total unsafe_func: 12
# std of unsafe_func: 5.366563145999495
# ==================================
# # average unsafe_block: 24.6
# # median unsafe_block: 2.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 114
# # total unsafe_block: 123
# std of unsafe_block: 50.05796639896591
# ==================================
# # average safe_func_fix: 900.0
# # median safe_func_fix: 929.0
# # minimum safe_func_fix: 96
# # maximum safe_func_fix: 1879
# # total safe_func_fix: 4500
# std of safe_func_fix: 667.4930711250867
# ==================================
# # average unsafe_func_fix: 0.6
# # median unsafe_func_fix: 0.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 3
# # total unsafe_func_fix: 3
# std of unsafe_func_fix: 1.3416407864998738
# ==================================
# # average unsafe_block_fix: 15.2
# # median unsafe_block_fix: 2.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 70
# # total unsafe_block_fix: 76
# std of unsafe_block_fix: 30.678983033992502
# ==================================
#
#
# Commit Locality Across Privilege
# Number of rows: 10
# # average safe_func: 1977.3
# # median safe_func: 886.5
# # minimum safe_func: 147
# # maximum safe_func: 9538
# # total safe_func: 19773
# std of safe_func: 3018.462929299539
# ==================================
# # average unsafe_func: 9.5
# # median unsafe_func: 0.5
# # minimum unsafe_func: 0
# # maximum unsafe_func: 56
# # total unsafe_func: 95
# std of unsafe_func: 17.507141400011598
# ==================================
# # average unsafe_block: 146.8
# # median unsafe_block: 12.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 1132
# # total unsafe_block: 1468
# std of unsafe_block: 349.8929360056682
# ==================================
# # average safe_func_fix: 1102.0
# # median safe_func_fix: 567.0
# # minimum safe_func_fix: 79
# # maximum safe_func_fix: 5664
# # total safe_func_fix: 11020
# std of safe_func_fix: 1742.1938914930092
# ==================================
# # average unsafe_func_fix: 5.3
# # median unsafe_func_fix: 0.5
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 34
# # total unsafe_func_fix: 53
# std of unsafe_func_fix: 10.456789394668156
# ==================================
# # average unsafe_block_fix: 83.8
# # median unsafe_block_fix: 6.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 616
# # total unsafe_block_fix: 838
# std of unsafe_block_fix: 190.07472214894858
# ==================================
#
#
# Commit Locality Across Resource Management
# Number of rows: 123
# # average safe_func: 1649.918699186992
# # median safe_func: 632.0
# # minimum safe_func: 1
# # maximum safe_func: 19805
# # total safe_func: 202940
# std of safe_func: 2769.775118389714
# ==================================
# # average unsafe_func: 16.008130081300813
# # median unsafe_func: 1.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 975
# # total unsafe_func: 1969
# std of unsafe_func: 89.0886918487818
# ==================================
# # average unsafe_block: 95.1951219512195
# # median unsafe_block: 30.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 3327
# # total unsafe_block: 11709
# std of unsafe_block: 324.77832688674573
# ==================================
# # average safe_func_fix: 1060.5691056910568
# # median safe_func_fix: 585.0
# # minimum safe_func_fix: 1
# # maximum safe_func_fix: 13469
# # total safe_func_fix: 130450
# std of safe_func_fix: 1723.7758311587093
# ==================================
# # average unsafe_func_fix: 10.495934959349594
# # median unsafe_func_fix: 1.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 599
# # total unsafe_func_fix: 1291
# std of unsafe_func_fix: 54.86845281660071
# ==================================
# # average unsafe_block_fix: 66.77235772357723
# # median unsafe_block_fix: 22.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 1586
# # total unsafe_block_fix: 8213
# std of unsafe_block_fix: 177.18184661704225
# ==================================
#
#
# Commit Locality Across Risky Values
# Number of rows: 19
# # average safe_func: 1440.2105263157894
# # median safe_func: 337.0
# # minimum safe_func: 10
# # maximum safe_func: 11669
# # total safe_func: 27364
# std of safe_func: 2993.0874913697644
# ==================================
# # average unsafe_func: 23.105263157894736
# # median unsafe_func: 2.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 353
# # total unsafe_func: 439
# std of unsafe_func: 80.20383389065785
# ==================================
# # average unsafe_block: 65.52631578947368
# # median unsafe_block: 22.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 477
# # total unsafe_block: 1245
# std of unsafe_block: 124.19848291301604
# ==================================
# # average safe_func_fix: 952.4736842105264
# # median safe_func_fix: 250.0
# # minimum safe_func_fix: 6
# # maximum safe_func_fix: 6225
# # total safe_func_fix: 18097
# std of safe_func_fix: 1747.83603885303
# ==================================
# # average unsafe_func_fix: 16.210526315789473
# # median unsafe_func_fix: 2.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 241
# # total unsafe_func_fix: 308
# std of unsafe_func_fix: 54.63675904184372
# ==================================
# # average unsafe_block_fix: 51.31578947368421
# # median unsafe_block_fix: 22.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 361
# # total unsafe_block_fix: 975
# std of unsafe_block_fix: 93.36252676266196
# ==================================
#
#
# Commit Locality Across Synchronization
# Number of rows: 30
# # average safe_func: 2462.1
# # median safe_func: 151.0
# # minimum safe_func: 3
# # maximum safe_func: 17370
# # total safe_func: 73863
# std of safe_func: 4860.676725625197
# ==================================
# # average unsafe_func: 40.06666666666667
# # median unsafe_func: 10.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 937
# # total unsafe_func: 1202
# std of unsafe_func: 170.11353882614407
# ==================================
# # average unsafe_block: 183.73333333333332
# # median unsafe_block: 62.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 3091
# # total unsafe_block: 5512
# std of unsafe_block: 558.7028038129984
# ==================================
# # average safe_func_fix: 1460.7666666666667
# # median safe_func_fix: 142.5
# # minimum safe_func_fix: 3
# # maximum safe_func_fix: 11898
# # total safe_func_fix: 43823
# std of safe_func_fix: 2923.3441134678496
# ==================================
# # average unsafe_func_fix: 26.266666666666666
# # median unsafe_func_fix: 7.5
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 571
# # total unsafe_func_fix: 788
# std of unsafe_func_fix: 103.60333283593074
# ==================================
# # average unsafe_block_fix: 111.76666666666667
# # median unsafe_block_fix: 57.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 1399
# # total unsafe_block_fix: 3353
# std of unsafe_block_fix: 256.0547736841412
# ==================================
#
#
# Commit Locality Across Tainted Input
# Number of rows: 85
# # average safe_func: 2469.0588235294117
# # median safe_func: 427.0
# # minimum safe_func: 10
# # maximum safe_func: 11671
# # total safe_func: 209870
# std of safe_func: 3813.3891761008817
# ==================================
# # average unsafe_func: 9.294117647058824
# # median unsafe_func: 1.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 121
# # total unsafe_func: 790
# std of unsafe_func: 19.539839357805672
# ==================================
# # average unsafe_block: 120.29411764705883
# # median unsafe_block: 22.0
# # minimum unsafe_block: 0
# # maximum unsafe_block: 1279
# # total unsafe_block: 10225
# std of unsafe_block: 264.6405839161148
# ==================================
# # average safe_func_fix: 1411.105882352941
# # median safe_func_fix: 304.0
# # minimum safe_func_fix: 10
# # maximum safe_func_fix: 6838
# # total safe_func_fix: 119944
# std of safe_func_fix: 2047.4409348043732
# ==================================
# # average unsafe_func_fix: 6.352941176470588
# # median unsafe_func_fix: 1.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 98
# # total unsafe_func_fix: 540
# std of unsafe_func_fix: 13.165345818937416
# ==================================
# # average unsafe_block_fix: 74.92941176470588
# # median unsafe_block_fix: 17.0
# # minimum unsafe_block_fix: 0
# # maximum unsafe_block_fix: 1148
# # total unsafe_block_fix: 6369
# std of unsafe_block_fix: 168.93565894370877
# ==================================

# %% [markdown]
# ### Fix patterns

# %%
df_data = load_commit_locality_frame()

# %%
# vulnerability locality: safe function
df_safe = df_data
df_safe = df_safe[df_safe["safe_func"]!=0]
print(len(df_safe))
add = len(df_safe[df_safe.apply(lambda x: True if x.safe_func < x.safe_func_fix else False, axis=1)])
remove = len(df_safe[df_safe.apply(lambda x: True if x.safe_func > x.safe_func_fix else False, axis=1)])
modified = len(df_safe[df_safe.apply(lambda x: True if x.safe_func == x.safe_func_fix else False, axis=1)])
print(add)
print(remove)
print(modified)
# Out:
# 555
# 10
# 505
# 40

# %%
df_unsafe = df_data
df_unsafe = df_unsafe[df_unsafe["unsafe_func"]!=0]
# df_unsafe = df_unsafe[df_unsafe["unsafe_block"]==0]
print(len(df_unsafe))
add = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_func < x.unsafe_func_fix else False, axis=1)])
modified = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_func ==x.unsafe_func_fix else False, axis=1)])
remove = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_func > x.unsafe_func else False, axis=1)])
print(add)
print(remove)
print(modified)
# Out:
# 318
# 3
# 0
# 110

# %%
df_unsafe = df_data
df_unsafe = df_unsafe[df_unsafe["unsafe_block"]!=0]
# df_unsafe = df_unsafe[df_unsafe["unsafe_block"]==0]
print(len(df_unsafe))
add = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_block < x.unsafe_block_fix else False, axis=1)])
modified = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_block == x.unsafe_block_fix else False, axis=1)])
remove = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_block > x.unsafe_block_fix else False, axis=1)])
print(add)
print(remove)
print(modified)
# Out:
# 444
# 5
# 324
# 115
