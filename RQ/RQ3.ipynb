# %%
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('../utils')
import database as db

# %%
def print_statistics(df_frame, col):
    print(f"# average {col}: " + str(df_frame[col].sum() / len(df_frame)))
    print(f"# median {col}: " + str(df_frame[col].median()))
    print(f"# minimum {col}: " + str(df_frame[col].min()))
    print(f"# maximum {col}: " + str(df_frame[col].max()))
    print(f"# total {col}: " + str(df_frame[col].sum()))
    print(f"std of {col}: " + str(df_frame[col].std()))
    print("==================================")


def load_commit_locality_frame():
    return pd.read_sql(
        """
        SELECT
            t.cve_id,
            t.hash,
            f.safe_func,
            f.unsafe_func,
            b.unsafe_block,
            ff.safe_func_fix AS safe_func_fix,
            ff.unsafe_func_fix  AS unsafe_func_fix,
            bf.unsafe_block_fix AS unsafe_block_fix,
            c.package,
            c.severity
        FROM total_safe_unsafe t
        LEFT JOIN (
            SELECT cve_id, hash,
                   SUM(CASE WHEN unsafety = 'False' THEN 1 ELSE 0 END) AS safe_func,
                   SUM(CASE WHEN unsafety = 'True'  THEN 1 ELSE 0 END) AS unsafe_func
            FROM function
            GROUP BY cve_id, hash
        ) f ON t.cve_id = f.cve_id AND t.hash = f.hash
        LEFT JOIN (
            SELECT cve_id, hash, COUNT(*) AS unsafe_block
            FROM unsafe_block
            GROUP BY cve_id, hash
        ) b ON t.cve_id = b.cve_id AND t.hash = b.hash
        LEFT JOIN (
            SELECT cve_id, hash,
                   SUM(CASE WHEN unsafety = 'False' THEN 1 ELSE 0 END) AS safe_func_fix,
                   SUM(CASE WHEN unsafety = 'True'  THEN 1 ELSE 0 END) AS unsafe_func_fix
            FROM function_fix
            GROUP BY cve_id, hash
        ) ff ON t.cve_id = ff.cve_id AND t.hash = ff.hash
        LEFT JOIN (
            SELECT cve_id, hash, COUNT(*) AS unsafe_block_fix
            FROM unsafe_block_fix
            GROUP BY cve_id, hash
        ) bf ON t.cve_id = bf.cve_id AND t.hash = bf.hash
        LEFT JOIN cve c ON t.cve_id = c.id
        """,
        con=db.conn,
    )

# %% [markdown]
# ### safe/unsafe in commit locality

# %%
df_data = load_commit_locality_frame()

print_statistics(df_data, 'safe_func')
print_statistics(df_data, 'unsafe_func')
print_statistics(df_data, 'unsafe_block')
print_statistics(df_data, 'safe_func_fix')
print_statistics(df_data, 'unsafe_func_fix')
print_statistics(df_data, 'unsafe_block_fix')
# Out:
# # average safe_func: 1637.6522522522523
# # median safe_func: 612.0
# # minimum safe_func: 1
# # maximum safe_func: 13446
# # total safe_func: 908897
# std of safe_func: 2237.591864836495
# ...
# # average unsafe_func: 21.08828828828829
# # median unsafe_func: 1.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 2676
# # total unsafe_func: 11704
# std of unsafe_func: 133.95061238881712
# ...
# # average unsafe_block: 115.77297297297298
# # median unsafe_block: 30.0
# # minimum unsafe_block: 1.0
# # maximum unsafe_block: 6481.0
# # total unsafe_block: 64254.0
# std of unsafe_block: 389.6439430492291
# ...
# # average safe_func_fix: 1638.7243243243242
# # median safe_func_fix: 615.0
# # minimum safe_func_fix: 0
# # maximum safe_func_fix: 13469
# # total safe_func_fix: 909492
# std of safe_func_fix: 2238.4698449991315
# ...
# # average unsafe_func_fix: 21.117117117117118
# # median unsafe_func_fix: 1.0
# # minimum unsafe_func_fix: 0
# # maximum unsafe_func_fix: 2676
# # total unsafe_func_fix: 11720
# ...

# %% [markdown]
# ### safe/unsafe in commit locality across type

# %%
df_data = load_commit_locality_frame()
df_types = pd.read_sql("SELECT cve_id, sfp_category FROM cve_sfp", con=db.conn)
df_data = df_data.merge(df_types, on='cve_id', how='left')

for category in sorted(df_data['sfp_category'].dropna().unique()):
    df_category = df_data[df_data['sfp_category'] == category]
    if df_category.empty:
        print(f"Category {category} is empty")
        continue

    print(f"Commit Locality Across {category}")
    print(f"Number of rows: {len(df_category)}")
    print_statistics(df_category, 'safe_func')
    print_statistics(df_category, 'unsafe_func')
    print_statistics(df_category, 'unsafe_block')
    print_statistics(df_category, 'safe_func_fix')
    print_statistics(df_category, 'unsafe_func_fix')
    print_statistics(df_category, 'unsafe_block_fix')
    print("\n")
# Out:
# Commit Locality Across API
# Number of rows: 9
# # average safe_func: 3305.5555555555557
# # median safe_func: 1720.0
# # minimum safe_func: 20
# # maximum safe_func: 9369
# # total safe_func: 29750
# std of safe_func: 3239.5917609751045
# ...
# # average unsafe_func: 59.22222222222222
# # median unsafe_func: 8.0
# # minimum unsafe_func: 0
# # maximum unsafe_func: 438
# # total unsafe_func: 533
# std of unsafe_func: 142.97183094737383
# ...
# # average unsafe_block: 149.77777777777777
# # median unsafe_block: 110.0
# # minimum unsafe_block: 7.0
# # maximum unsafe_block: 732.0
# # total unsafe_block: 1348.0
# std of unsafe_block: 247.65625178383658
# ...
# # average safe_func_fix: 3306.8888888888887
# # median safe_func_fix: 1720.0
# # minimum safe_func_fix: 20
# # maximum safe_func_fix: 9371
# # total safe_func_fix: 29762
# std of safe_func_fix: 3240.1718104309084
# ...
# # average unsafe_func_fix: 59.44444444444444
# # median unsafe_func_fix: 8.0
# # minimum unsafe_func_fix: 0
# ...

# %% [markdown]
# ### Fix patterns

# %%
df_data = load_commit_locality_frame()

# %%
# vulnerability locality: safe function
df_safe = df_data
df_safe = df_safe[df_safe["safe_func"]!=0]
print(len(df_safe))
add = len(df_safe[df_safe.apply(lambda x: True if x.safe_func < x.safe_func_fix else False, axis=1)])
remove = len(df_safe[df_safe.apply(lambda x: True if x.safe_func > x.safe_func_fix else False, axis=1)])
modified = len(df_safe[df_safe.apply(lambda x: True if x.safe_func == x.safe_func_fix else False, axis=1)])
print(add)
print(remove)
print(modified)
# Out:
# 555
# 168
# 20
# 367

# %%
df_unsafe = df_data
df_unsafe = df_unsafe[df_unsafe["unsafe_func"]!=0]
# df_unsafe = df_unsafe[df_unsafe["unsafe_block"]==0]
print(len(df_unsafe))
add = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_func < x.unsafe_func_fix else False, axis=1)])
modified = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_func ==x.unsafe_func_fix else False, axis=1)])
remove = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_func > x.unsafe_func_fix else False, axis=1)])
print(add)
print(remove)
print(modified)
# Out:
# 318
# 9
# 3
# 306

# %%
df_unsafe = df_data
df_unsafe = df_unsafe[df_unsafe["unsafe_block"]!=0]
# df_unsafe = df_unsafe[df_unsafe["unsafe_block"]==0]
print(len(df_unsafe))
add = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_block < x.unsafe_block_fix else False, axis=1)])
modified = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_block == x.unsafe_block_fix else False, axis=1)])
remove = len(df_unsafe[df_unsafe.apply(lambda x: True if x.unsafe_block > x.unsafe_block_fix else False, axis=1)])
print(add)
print(remove)
print(modified)
# Out:
# 555
# 24
# 15
# 397

# %% [markdown]
# ### Fix patterns across vulnerability type
#
# Breakdown of the global fix patterns (cells 8–10) by vulnerability type, using the same SFP grouping as RQ7:
# **Memory** = Memory Access + Memory Management, **RM** = Resource Management, everything else is **Other**.
#
# The chi-squared test requires mutually exclusive groups, so each CVE is assigned to its **primary category (first listed SFP category)** and each fix is counted in exactly one group — even though 266 CVEs span multiple SFP categories. (Counting a fix in every group it belongs to would double-count it and violate the independence assumption.)
#
# For each type we report, of the fixes touching code that contains the construct pre-fix (`col != 0`, as in cells 8–10), the share that **added / removed / left unchanged** the number of unsafe functions and unsafe blocks. Because the 'added' cells are sparse (expected counts < 5), the asymptotic chi-squared p-value is confirmed with a permutation test (exact conditional distribution with fixed margins).

# %%
from scipy.stats import chi2_contingency
import numpy as np

def classify_vul_type(sfp_category):
    """Classify SFP category into Memory / Resource Management / Other (as in RQ7)."""
    if sfp_category in ['Memory Access', 'Memory Management']:
        return 'Memory'
    elif sfp_category == 'Resource Management':
        return 'Resource Management'
    else:
        return 'Other'

# Primary category = first listed SFP category per CVE, so the groups are
# mutually exclusive (required for the chi-squared test): a fix is counted in
# exactly one group even if its CVE spans several SFP categories.
df_types = pd.read_sql(
    "SELECT cve_id, sfp_category FROM cve_sfp ORDER BY rowid", con=db.conn)
df_types['vul_type'] = df_types['sfp_category'].apply(classify_vul_type)
df_primary = df_types.drop_duplicates('cve_id', keep='first')[['cve_id', 'vul_type']]

df_typed = df_data.merge(df_primary, on='cve_id', how='left')

VUL_TYPES = ['Memory', 'Resource Management', 'Other']

def pattern_counts(df, col, col_fix):
    """add/remove/unchanged counts, restricted to fixes where the construct exists
    pre-fix (col != 0), matching the global analysis in cells 8-10."""
    df = df[df[col] != 0]
    add = (df[col] < df[col_fix]).sum()
    remove = (df[col] > df[col_fix]).sum()
    unchanged = (df[col] == df[col_fix]).sum()
    return add, remove, unchanged

def permutation_pvalue(observed, B=50000, seed=42):
    """Exact conditional independence test (fixed margins): permute the pattern
    labels and recompute Pearson's chi-squared statistic. Reliable despite
    sparse 'added' cells where the asymptotic chi-squared approximation fails."""
    rng = np.random.default_rng(seed)
    observed = np.asarray(observed, dtype=int)
    chi2_obs = chi2_contingency(observed).statistic
    groups = np.concatenate([np.full(observed[r, c], r)
                             for r in range(3) for c in range(3)])
    patterns = np.concatenate([np.full(observed[r, c], c)
                               for r in range(3) for c in range(3)])
    expected = np.outer(observed.sum(axis=1), observed.sum(axis=0)) / len(groups)
    count = 0
    for _ in range(B):
        perm = rng.permutation(patterns)
        table = np.bincount(groups * 3 + perm, minlength=9).reshape(3, 3)
        if ((table - expected) ** 2 / expected).sum() >= chi2_obs - 1e-12:
            count += 1
    return chi2_obs, (count + 1) / (B + 1)

for col, col_fix, label in [
    ('safe_func', 'safe_func_fix', 'Safe functions'),
    ('unsafe_func', 'unsafe_func_fix', 'Unsafe functions'),
    ('unsafe_block', 'unsafe_block_fix', 'Unsafe blocks'),
]:
    print(f"{label}: fix pattern by vulnerability type (primary category, mutually exclusive)")
    counts = []
    for vt in VUL_TYPES:
        sub = df_typed[df_typed['vul_type'] == vt]
        add, remove, unchanged = pattern_counts(sub, col, col_fix)
        n = add + remove + unchanged
        counts.append([add, remove, unchanged])
        print(f"  {vt:20s} n={n:4d}  added {add:3d} ({add/n*100:4.1f}%)  "
              f"removed {remove:3d} ({remove/n*100:4.1f}%)  "
              f"unchanged {unchanged:3d} ({unchanged/n*100:4.1f}%)")

    chi2, p, dof, expected = chi2_contingency(counts)
    chi2_perm, p_perm = permutation_pvalue(counts)
    verdict = ('fix patterns DEPEND on vuln type' if p_perm < 0.05
               else 'fix patterns are independent of vuln type (p >= 0.05)')
    print(f"  chi-squared: chi2={chi2:.2f}, dof={dof}, asymptotic p={p:.4f} "
          f"(note: {int((expected < 5).sum())} cells have expected count < 5)")
    print(f"  permutation test (B=50000): chi2={chi2_perm:.2f}, p={p_perm:.4f}")
    print(f"  -> {verdict}")
    print()
# Out:
# Safe functions: fix pattern by vulnerability type (primary category, mutually exclusive)
#   Memory               n=  88  added  10 (11.4%)  removed   6 ( 6.8%)  unchanged  72 (81.8%)
#   Resource Management  n=  90  added  28 (31.1%)  removed   1 ( 1.1%)  unchanged  61 (67.8%)
#   Other                n= 293  added 102 (34.8%)  removed  10 ( 3.4%)  unchanged 181 (61.8%)
#   chi-squared: chi2=20.79, dof=4, asymptotic p=0.0003 (note: 2 cells have expected count < 5)
#   permutation test (B=50000): chi2=20.79, p=0.0004
#   -> fix patterns DEPEND on vuln type
#
# Unsafe functions: fix pattern by vulnerability type (primary category, mutually exclusive)
#   Memory               n=  67  added   3 ( 4.5%)  removed   3 ( 4.5%)  unchanged  61 (91.0%)
#   Resource Management  n=  39  added   1 ( 2.6%)  removed   0 ( 0.0%)  unchanged  38 (97.4%)
#   Other                n= 155  added   2 ( 1.3%)  removed   0 ( 0.0%)  unchanged 153 (98.7%)
# ...
